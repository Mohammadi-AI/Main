# %% [markdown]
# Calculate the score of football matches
#
#
# sample of data inpit and output
#
#  please enter each team scores
#
# **************************************************
#
# IRAN vs Spain
# Enter IRAN goals number1
# Enter Spain goals number1
#
# **************************************************
#
# IRAN vs Portugal
# Enter IRAN goals number2
# Enter Portugal goals number0
#
# **************************************************
#
# IRAN vs Moroco
# Enter IRAN goals number3
# Enter Moroco goals number0
#
# **************************************************
#
# Portugal vs Spain
# Enter portugal goals number1
# Enter Spain goals number0
#
# **************************************************
#
# Moroco vs Spain
# Enter Moroco goals number3
# Enter Spain goals number0
#
# **************************************************
#
# Portugal vs Moroco
# Enter portugal goals number1
# Enter Moroco goals number1
#
# **************************************************
#
# Points|Wins|loses|dreaws|goaldifferenses
# [7, 2, 0, 1, 5, 'Iran']
# [4, 1, 1, 1, 0, 'Morocco']
# [4, 1, 1, 1, -1, 'portugal']
# [1, 0, 2, 1, -4, 'Spain']

# %%
print(" please enter each team scores ")
print()
print('*'*50)
print()



iranpoint=iranwins=iranloses=irandraws=irangoaldif=0 
spainpoint=spainwins=spainloses=spaindraws=spaingoaldif=0
morocopoint=morocowins=morocoloses=morocodraws=morocogoaldif=0
portugalpoint=portugalwins=portugalloses=portugaldraws=portugalgoaldif=0

print("IRAN vs Spain")
irangoals=int(input("Enter IRAN goals number"))
spaingoals=int(input("Enter Spain goals number"))

if irangoals > spaingoals :
    iranpoint+=3
    iranwins+=1
    irangoaldif+=(irangoals-spaingoals)
    spainloses+=1
    spaingoaldif+=(spaingoals-irangoals)
    
elif irangoals < spaingoals :
    spainpoint+=3
    spainwins+=1
    spaingoaldif+=(spaingoals-irangoals)
    iranloses+=1
    irangoaldif+=(irangoals-spaingoals)
    
else:
    iranpoint+=1
    irandraws+=1
    spainpoint+=1
    spaindraws+=1


print()
print('*'*50)
print()
print("IRAN vs Portugal")
irangoals=int(input("Enter IRAN goals number"))
portugalgoals=int(input("Enter Portugal goals number"))

if irangoals > portugalgoals :
    iranpoint+=3
    iranwins+=1
    irangoaldif+=(irangoals-portugalgoals)
    portugalloses+=1
    portugalgoaldif+=(portugalgoals-irangoals)
    
elif irangoals < portugalgoals :
    portugalpoint+=3
    portugalwins+=1
    portugalgoaldif+=(portugalgoals-irangoals)
    iranloses+=1
    irangoaldif+=(irangoals-portugalgoals)
    
else:
    iranpoint+=1
    irandraws+=1
    portugalpoint+=1
    portugaldraws+=1

print()
print('*'*50)
print()

print("IRAN vs Moroco")
irangoals=int(input("Enter IRAN goals number"))
morocogoals=int(input("Enter Moroco goals number"))

if irangoals > morocogoals :
    iranpoint+=3
    iranwins+=1
    irangoaldif+=(irangoals-morocogoals)
    morocoloses+=1
    morocogoaldif+=(morocogoals-irangoals)
    
elif irangoals < morocogoals :
    morocopoint+=3
    morocowins+=1
    morocogoaldif+=(morocogoals-irangoals)
    iranloses+=1
    irangoaldif+=(irangoals-morocogoals)
    
else:
    iranpoint+=1
    irandraws+=1
    morocopoint+=1
    morocodraws+=1  
    
print()
print('*'*50)
print()

print("Portugal vs Spain")
portugalgoals=int(input("Enter portugal goals number"))
spaingoals=int(input("Enter Spain goals number"))

if portugalgoals > spaingoals :
    portugalpoint+=3
    portugalwins+=1
    portugalgoaldif+=(portugalgoals-spaingoals)
    spainloses+=1
    spaingoaldif+=(spaingoals-portugalgoals)
    
elif portugalgoals < spaingoals :
    spainpoint+=3
    spainwins+=1
    spaingoaldif+=(spaingoals-portugalgoals)
    portugalloses+=1
    portugalgoaldif+=(portugalgoals-spaingoals)
    
else:
    portugalpoint+=1
    portugaldraws+=1
    spainpoint+=1
    spaindraws+=1

print()
print('*'*50)
print()

print("Moroco vs Spain")
morocogoals=int(input("Enter Moroco goals number"))
spaingoals=int(input("Enter Spain goals number"))

if morocogoals > spaingoals :
    morocopoint+=3
    morocowins+=1
    morocogoaldif+=(morocogoals-spaingoals)
    spainloses+=1
    spaingoaldif+=(spaingoals-morocogoals)
    
elif morocogoals < spaingoals :
    spainpoint+=3
    spainwins+=1
    spaingoaldif+=(spaingoals-morocogoals)
    morocoloses+=1
    morocogoaldif+=(morocogoals-spaingoals)
    
else:
    morocopoint+=1
    morocodraws+=1
    spainpoint+=1
    spaindraws+=1

print()
print('*'*50)
print()

print("Portugal vs Moroco")
portugalgoals=int(input("Enter portugal goals number"))
morocogoals=int(input("Enter Moroco goals number"))

if portugalgoals > morocogoals :
    portugalpoint+=3
    portugalwins+=1
    portugalgoaldif+=(portugalgoals-morocogoals)
    morocoloses+=1
    morocogoaldif+=(morocogoals-portugalgoals)
    
elif portugalgoals < morocogoals :
    morocopoint+=3
    morocowins+=1
    morocogoaldif+=(morocogoals-portugalgoals)
    portugalloses+=1
    portugalgoaldif+=(portugalgoals-morocogoals)
    
else:
    portugalpoint+=1
    portugaldraws+=1
    morocopoint+=1
    morocodraws+=1
    

iran="Iran"
spain="Spain"
portugal="Portugal"
moroco="Morocco"

table=[
       [iranpoint ,iranwins, iranloses,irandraws,irangoaldif,iran],
       [spainpoint , spainwins, spainloses,spaindraws,spaingoaldif,spain],
       [portugalpoint ,portugalwins, portugalloses,portugaldraws,portugalgoaldif,portugal],
       [morocopoint , morocowins,morocoloses,morocodraws,morocogoaldif,moroco]
     ]


print()
print('*'*50)
print()
print("Points","Wins","loses","dreaws","goaldifferenses", sep="|")


finaltable=[]
finaltable=table
finaltable.sort()
finaltable.reverse()
for team in finaltable:
    print(team)
# Out:
#  please enter each team scores
#
# **************************************************
#
# IRAN vs Spain
# Enter IRAN goals number2
# Enter Spain goals number2
#
# **************************************************
#
# IRAN vs Portugal
# Enter IRAN goals number2
# Enter Portugal goals number1
#
# **************************************************
#
# IRAN vs Moroco
# Enter IRAN goals number1
# Enter Moroco goals number2
#
# **************************************************
#
# Portugal vs Spain
# Enter portugal goals number2
# Enter Spain goals number2
#
# **************************************************
#
# Moroco vs Spain
# Enter Moroco goals number1
# Enter Spain goals number3
#
# **************************************************
#
# Portugal vs Moroco
# Enter portugal goals number2
# Enter Moroco goals number1
#
# **************************************************
#
# Points|Wins|loses|dreaws|goaldifferenses
# [5, 1, 0, 2, 2, 'Spain']
# [4, 1, 1, 1, 0, 'Portugal']
# ...
