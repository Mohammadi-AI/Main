# %% [markdown]
# this program Shows the popularity of of different movie genres. each person 6 choice.
#
#
# sample input and output
#
#
# please enter the number of people3
# please write your namehamid
# please choose the number of your favorite movies
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 5
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 6
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 0
# please write your namemina
# please choose the number of your favorite movies
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 6
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 5
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 4
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 2
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 0
# please write your namehamid
# please choose the number of your favorite movies
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 6
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 5
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 4
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 0
#
# ****************************************
# ('Adventure', 3)
# ('Action', 3)
# ('History', 2)
# ('Romance', 1)
# ('Horror', 0)
# ('Comedy', 0)

# %%
horror=romance=comedy=history=adventure=action=0
number=int(input("please enter the number of people"))
for i in range (0, number):
    name = input("please write your name")
    count=0
    print("please choose the number of your favorite movies")
    choose=""
    while choose!="0" :
        choose=input("for exit type 0 \n 1-Horror \n 2-Romance \n 3-Comedy \n 4-History \n 5-Adventure \n 6-Action \n")
        count+=1
        if count>6:
            break
        if choose=="0":
            break
        
        elif choose=="1" :
            horror+=1
            
       
        elif choose=="2" :
            romance+=1
            
        
        elif choose=="3":
            comedy+=1
            
            
        elif choose=="4":
            history+=1
            
            
        elif choose=="5":
            adventure+=1
            
            
        elif choose=="6":
            action+=1
            
print()
print('*'*40)
table={    "Horror":horror,
             "Romance":romance,
             "Comedy":comedy,
             "History":history,
             "Adventure":adventure,
             "Action":action
        }



sorted_by_values=(sorted(table.items(), key=lambda x: x[1],reverse=True))
for f in sorted_by_values :
    print(f)
# Out:
# please enter the number of people3
# please write your namehamid
# please choose the number of your favorite movies
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 5
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 6
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 0
# please write your namemina
# please choose the number of your favorite movies
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 6
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 5
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 4
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 2
# for exit type 0
#  1-Horror
#  2-Romance
#  3-Comedy
#  4-History
#  5-Adventure
#  6-Action
# 0
# ...
